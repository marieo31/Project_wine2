# %%
import pandas as pd

# %%
filepath =  r"../Resources_cleaned/winemag_full.json"

df = pd.read_json(filepath)
df.head()
# Out:
#    Year country                                        description  \
# 0  2013      US  Tart and snappy, the flavors of lime flesh and...
# 1  2013      US  Pineapple rind, lemon pith and orange blossom ...
# 2  2012      US  Much like the regular bottling from 2012, this...
# 3  2011   Spain  Blackberry and raspberry aromas show a typical...
# 4  2013   Italy  Here's a bright, informal red that opens with ...
#
#                           designation  index  level_0  points  price  \
# 0                                None      2        0      87     14
# 1                Reserve Late Harvest      3        1      87     13
# 2  Vintner's Reserve Wild Child Block      4        2      87     65
# 3                        Ars In Vitro      5        3      87     15
# 4                             Belsito      6        4      87     16
#
#             province             region_1           region_2  \
# 0             Oregon    Willamette Valley  Willamette Valley
# ...

# %%
df.count()
# Out:
# Year                     107288
# country                  107288
# description              107288
# designation               74866
# index                    107288
# level_0                  107288
# points                   107288
# price                    107288
# province                 107288
# region_1                 101146
# region_2                  50292
# taster_name               82952
# taster_twitter_handle     79976
# title                    107288
# variety                  107287
# winery                   107288
# dtype: int64

# %%
df.describe()
# Out:
#                index        level_0         points          price
# count  107288.000000  107288.000000  107288.000000  107288.000000
# mean    65065.465933   53643.500000      88.365866      36.065003
# std     37509.313046   30971.522178       3.064732      41.192884
# min         2.000000       0.000000      80.000000       4.000000
# 25%     32687.750000   26821.750000      86.000000      18.000000
# 50%     65153.000000   53643.500000      88.000000      26.000000
# 75%     97557.250000   80465.250000      91.000000      44.000000
# max    129970.000000  107287.000000     100.000000    3300.000000

# %%
df.sort_values(['points'], ascending=False)
# Out:
#         Year    country                                        description  \
# 37659   2006         US  Tasted in a flight of great and famous Napa wi...
# 74018   2008     France  This latest incarnation of the famous brand is...
# 92193   2010     France  A hugely powerful wine, full of dark, brooding...
# 92192   2010     France  This is the finest Cheval Blanc for many years...
# 29938   2002     France  This is a fabulous wine from the greatest Cham...
# 93988   2006         US  In 2005 Charles Smith introduced three high-en...
# 92191   2007      Italy  It takes only a few moments before you appreci...
# 92190   2010     France  Almost black in color, this stunning wine is g...
# 32246   2007      Italy  A perfect wine from a classic vintage, the 200...
# 74019   2006     France  This new release from a great vintage for Char...
# 48059   2010     France  This is a magnificently solid wine, initially ...
# ...

# %%
df_top10 = df.sort_values(['price'], ascending=False) #.iloc[0:11]
df_top10 = df_top10.drop(["level_0"], axis=1)
df_top10 = df_top10.reset_index()

df_top10 = df_top10.drop(df_top10.index[3])
df_top10
# Out:
#         level_0  Year       country  \
# 0         66208  2013        France
# 1         81149  2010        France
# 2         13074  2014        France
# 4         93675  2005        France
# 5         53809  2011        France
# 6          1313  2009        France
# 7         92190  2010        France
# 8         92192  2010        France
# 9          1329  2009        France
# 10         1326  2009        France
# 11        93688  2006        France
# 12         1321  2009        France
# 13        57291  2009        France
# 14        69974  2014        France
# 15        44728  2013        France
# 16        73300  2006         Italy
# 17        24721  2014        France
# 18       102715  2007        France
# 19        63527  2008     Australia
# 20        46935  2010     Australia
# 21       101488  2014        France
# 22        46941  2010     Australia
# 23        32248  2007        France
# 24        80140  2014        France
# 25        93989  2005        France
# ...

# %%
df.loc[df["points"]==100]
# Out:
#         Year    country                                        description  \
# 295           Australia  This wine contains some material over 100 year...
# 6084    1995      Italy  Thick as molasses and dark as caramelized brow...
# 29938   2002     France  This is a fabulous wine from the greatest Cham...
# 32246   2007      Italy  A perfect wine from a classic vintage, the 200...
# 37643   2010      Italy  This gorgeous, fragrant wine opens with classi...
# 37659   2006         US  Tasted in a flight of great and famous Napa wi...
# 48059   2010     France  This is a magnificently solid wine, initially ...
# 74018   2008     France  This latest incarnation of the famous brand is...
# 74019   2006     France  This new release from a great vintage for Char...
# 92190   2010     France  Almost black in color, this stunning wine is g...
# 92191   2007      Italy  It takes only a few moments before you appreci...
# ...

# %%
df.loc[df["points"]==100].mean()
# Out:
# Year       1.173647e+62
# index      7.872747e+04
# level_0    6.492053e+04
# points     1.000000e+02
# price      4.784118e+02
# dtype: float64

# %%
df.groupby("country").mean()
# Out:
#                       index       level_0     points      price
# country
# Argentina      65039.656283  53624.899627  86.710330  24.510117
# Australia      65065.867916  53642.618570  88.595466  35.437663
# Chile          64585.023777  53250.185236  86.495471  20.786458
# China         109989.000000  90752.000000  89.000000  18.000000
# France         64847.977779  53463.316550  88.734867  41.139120
# Italy          64184.232648  52914.732884  88.618186  39.663770
# South Africa   65606.969064  54092.717711  87.831400  24.668987
# Spain          64905.117146  53510.684923  87.290735  28.215275
# US             65457.943334  53967.707454  88.566387  36.573464
